# %% [markdown]
# # CSV read and write with pandas

# %% [markdown]
# # Document

# %% [markdown]
# <table align="left">
#     <tr>
#         <th class="text-align:left">Title</th>
#         <td class="text-align:left">CSV read and write in pandas</td>
#     </tr>
#     <tr>
#         <th class="text-align:left">Last modified</th>
#         <td class="text-align:left">2018-09-11</td>
#     </tr>
#     <tr>
#         <th class="text-align:left">Author</th>
#         <td class="text-align:left">Gilles Pilon <gillespilon13@gmail.com></td>
#     </tr>
#     <tr>
#         <th class="text-align:left">Status</th>
#         <td class="text-align:left">Active</td>
#     </tr>
#     <tr>
#         <th class="text-align:left">Type</th>
#         <td class="text-align:left">Jupyter notebook</td>
#     </tr>
#     <tr>
#         <th class="text-align:left">Created</th>
#         <td class="text-align:left">2018-09-10</td>
#     </tr>
#     <tr>
#         <th class="text-align:left">File name</th>
#         <td class="text-align:left">csv_read_write_pandas.ipynb</td>
#     </tr>
#     <tr>
#         <th class="text-align:left">Other files required</th>
#         <td class="text-align:left"></td>
#     </tr>
# </table>

# %% [markdown]
# # In brevi
#
# The purpose of this Jupyter notebook is to illustrate how to read and write CSV files with pandas.

# %% [markdown]
# # Code

# %% [markdown]
# ## Import libraries

# %%
# Import librairies
import pandas as pd
# Out:
# /home/gilles/.pyenv/versions/3.6.6/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/gilles/.pyenv/versions/3.6.6/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %% [markdown]
# ## Create dataframe

# %%
# Create a dataframe to write and read.
data = {'stagefirst':  ['Moe', 'Larry', 'Curly', 'Shemp', 'Curly Joe','Joe'],
        'stagelast':   ['Howard', 'Fine', '.', 'Howard', 'DeRita', 'Besser'],
        'realfirst':   ['Moses Harry', 'Louis', 'Jerome Lester', 'Samuel', 'Joseph', 'Joe'],
        'reallast':    ['Horwitz', 'Feinberg', 'Horwitz', 'Horwitz', 'Wardell', 'Besser'],
        'born':        ['1897-06-19', '1902-10-05', '1903-10-22', '1895-03-11', '1909-07-12', '1907-08-12'],
        'died':        ['1975-05-04', '1975-01-24', '1952-01-18', '1955-11-22', '1993-07-03', '1988-03-01'],
        'age':         [77, 72, 48, 60, 83, 80],
        'height':      [114, 124, 131, '.', '.', '.'],
        'weight':      ['25,000', '94,000', 157, 162, 170, 200]
       }
df = pd.DataFrame.from_dict(data, orient='columns')
df
# Out:
#   stagefirst stagelast      realfirst  reallast        born        died  age  \
# 0        Moe    Howard    Moses Harry   Horwitz  1897-06-19  1975-05-04   77
# 1      Larry      Fine          Louis  Feinberg  1902-10-05  1975-01-24   72
# 2      Curly         .  Jerome Lester   Horwitz  1903-10-22  1952-01-18   48
# 3      Shemp    Howard         Samuel   Horwitz  1895-03-11  1955-11-22   60
# 4  Curly Joe    DeRita         Joseph   Wardell  1909-07-12  1993-07-03   83
# 5        Joe    Besser            Joe    Besser  1907-08-12  1988-03-01   80
#
#   height  weight
# 0    114  25,000
# 1    124  94,000
# 2    131     157
# 3      .     162
# 4      .     170
# 5      .     200

# %% [markdown]
# ## Write dataframe

# %%
# Write the dataframe to the current working directory.
df.to_csv('data.csv')

# %% [markdown]
# ## Read dataframe

# %%
# Read a data file to a dataframe.
df = pd.read_csv('data.csv')
df
# Out:
#    Unnamed: 0 stagefirst stagelast      realfirst  reallast        born  \
# 0           0        Moe    Howard    Moses Harry   Horwitz  1897-06-19
# 1           1      Larry      Fine          Louis  Feinberg  1902-10-05
# 2           2      Curly         .  Jerome Lester   Horwitz  1903-10-22
# 3           3      Shemp    Howard         Samuel   Horwitz  1895-03-11
# 4           4  Curly Joe    DeRita         Joseph   Wardell  1909-07-12
# 5           5        Joe    Besser            Joe    Besser  1907-08-12
#
#          died  age height  weight
# 0  1975-05-04   77    114  25,000
# 1  1975-01-24   72    124  94,000
# 2  1952-01-18   48    131     157
# 3  1955-11-22   60      .     162
# 4  1993-07-03   83      .     170
# 5  1988-03-01   80      .     200

# %%
# Read a data file to a dataframe without column names.
df= pd.read_csv('data.csv', header=None)
df
# Out:
#      0           1          2              3         4           5  \
# 0  NaN  stagefirst  stagelast      realfirst  reallast        born
# 1  0.0         Moe     Howard    Moses Harry   Horwitz  1897-06-19
# 2  1.0       Larry       Fine          Louis  Feinberg  1902-10-05
# 3  2.0       Curly          .  Jerome Lester   Horwitz  1903-10-22
# 4  3.0       Shemp     Howard         Samuel   Horwitz  1895-03-11
# 5  4.0   Curly Joe     DeRita         Joseph   Wardell  1909-07-12
# 6  5.0         Joe     Besser            Joe    Besser  1907-08-12
#
#             6    7       8       9
# 0        died  age  height  weight
# 1  1975-05-04   77     114  25,000
# 2  1975-01-24   72     124  94,000
# 3  1952-01-18   48     131     157
# 4  1955-11-22   60       .     162
# 5  1993-07-03   83       .     170
# 6  1988-03-01   80       .     200

# %%
# Read a data file to a dataframe. Specify the column names.
df = pd.read_csv('data.csv',
                 names = ['ID', 'Stage First', 'Stage Last', 'Real First', 'Real Last', 'Age', 'Ht', 'Wt'])
df
# Out:
#                        ID    Stage First Stage Last  Real First   Real Last  \
# NaN stagefirst  stagelast      realfirst   reallast        born        died
# 0.0 Moe            Howard    Moses Harry    Horwitz  1897-06-19  1975-05-04
# 1.0 Larry            Fine          Louis   Feinberg  1902-10-05  1975-01-24
# 2.0 Curly               .  Jerome Lester    Horwitz  1903-10-22  1952-01-18
# 3.0 Shemp          Howard         Samuel    Horwitz  1895-03-11  1955-11-22
# 4.0 Curly Joe      DeRita         Joseph    Wardell  1909-07-12  1993-07-03
# 5.0 Joe            Besser            Joe     Besser  1907-08-12  1988-03-01
#
#                 Age      Ht      Wt
# NaN stagefirst  age  height  weight
# 0.0 Moe          77     114  25,000
# 1.0 Larry        72     124  94,000
# 2.0 Curly        48     131     157
# 3.0 Shemp        60       .     162
# 4.0 Curly Joe    83       .     170
# 5.0 Joe          80       .     200

# %%
# Read a data file to a dataframe. Specify the column labels.
# Skip the first row of the file, which contains column names.
df = pd.read_csv('data.csv',
                 skiprows=1,
                 names = ['ID', 'Stage First', 'Stage Last', 'Real First', 'Real Last', 'Age', 'Ht', 'Wt'])
df
# Out:
#                  ID    Stage First Stage Last  Real First   Real Last  Age  \
# 0 Moe        Howard    Moses Harry    Horwitz  1897-06-19  1975-05-04   77
# 1 Larry        Fine          Louis   Feinberg  1902-10-05  1975-01-24   72
# 2 Curly           .  Jerome Lester    Horwitz  1903-10-22  1952-01-18   48
# 3 Shemp      Howard         Samuel    Horwitz  1895-03-11  1955-11-22   60
# 4 Curly Joe  DeRita         Joseph    Wardell  1909-07-12  1993-07-03   83
# 5 Joe        Besser            Joe     Besser  1907-08-12  1988-03-01   80
#
#               Ht      Wt
# 0 Moe        114  25,000
# 1 Larry      124  94,000
# 2 Curly      131     157
# 3 Shemp        .     162
# 4 Curly Joe    .     170
# 5 Joe          .     200

# %%
# Read a data file to a dataframe. Specify the column labels.
# Skip the first row of the file, which contains column names.
# Set the index column to ID.
df = pd.read_csv('data.csv',
                 skiprows=1, index_col='ID',
                 names = ['ID', 'Stage First', 'Stage Last', 'Real First', 'Real Last', 'Age', 'Ht', 'Wt'])
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-4e81b7dfd8d9> in <module>()
#       4 df = pd.read_csv('data.csv',
#       5                  skiprows=1, index_col='ID',
# ----> 6                  names = ['ID', 'Stage First', 'Stage Last', 'Real First', 'Real Last', 'Age', 'Ht', 'Wt'])
#       7 df
#
# ~/.pyenv/versions/3.6.6/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# ~/.pyenv/versions/3.6.6/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     444
#     445     try:
# --> 446         data = parser.read(nrows)
#     447     finally:
#     448         parser.close()
#
# ~/.pyenv/versions/3.6.6/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1034                 raise ValueError('skipfooter not supported for iteration')
#    1035
# -> 1036         ret = self._engine.read(nrows)
#    1037
#    1038         # May alter columns / col_dict
#
# ~/.pyenv/versions/3.6.6/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1884                     values = data.pop(i)
#    1885                 else:
# -> 1886                     values = data.pop(self.index_col[i])
#    1887
#    1888                 values = self._maybe_parse_dates(values, i,
#
# KeyError: 'ID'

# %%
# Read a data file to a dataframe. Specify the column labels.
# Skip the first row of the file, which contains column names.
# Set the index column to first and last names.
df = pd.read_csv('data.csv', index_col=[1,2])
df.index.names = ['Stage First', 'Stage Last']
df.columns = ['ID', 'Real First', 'Real Last', 'Age', 'Ht', 'Wt']
df

# %%
# Read a data file to a dataframe. Specify the column labels.
# Skip the first row of the file, which contains column names.
# Set the index column to first and last names.
df = pd.read_csv('data.csv', index_col=[1,2])
df.index.names = ['Stage First', 'Stage Last']
df.columns = ['ID', 'Real First', 'Real Last', 'Age', 'Ht', 'Wt']
df

# %%
# Read a data file. Specify '.' as NaN.
df = pd.read_csv('data.csv', na_values=['.'])
df

# %%
pd.isnull(df)

# %%
# Read a data file. Specify '.' and 'NA' as missing values.
notable = {'last': ['.', 'NA'], 'height': ['.']}
df = pd.read_csv('data.csv', na_values=notable)
df

# %%
# Read a data file. Interpret strings around numbers as 'thousands' separators.
df = pd.read_csv('data.csv', thousands=',')
df
